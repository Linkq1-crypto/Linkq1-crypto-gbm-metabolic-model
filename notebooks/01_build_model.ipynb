# %% [markdown]
# # 01 - Caricamento e Validazione Modelli
# In questo notebook carichiamo i dati da `data/raw` usando i moduli in `src/`.

# %%
from src.loader import load_all_raw_models, load_sbml
models = load_all_raw_models()
print(f'Trovati {len(models)} modelli.')

# %%
# Esempio caricamento primo modello
if models:
    m = load_sbml(models[0])
    print(m.summary())
